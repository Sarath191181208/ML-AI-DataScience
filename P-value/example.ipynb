# %% [markdown]
# # Hypothesis testing (p-value)

# %% [markdown]
# Quick Navigate:
# - [T-test](#t-test)
#   - [One sample t test](#one-sample-t-test)
#   - [Two sample t test](#two-sample-t-test)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

## use display for html output
from IPython.display import display, HTML

# auto-reload modules
# %load_ext autoreload
# %autoreload 2

# %%
plt.style.use('dark_background')

# %% [markdown]
# # T-test

# %% [markdown]
# ## One sample T-test

# %% [markdown]
# - Mean and sample are different or not.
#
# $
#  t = \frac{\bar{x} - \mu}{s_{\bar{x}}}
#  \hspace{1cm}
#  Where,  s_{\bar{x}} = \frac{s}{\sqrt{n}}
# $
#
# Where,
# - $\mu$ : assumed mean.
# - $\bar{x}$: actual mean.
# - $n$ : sample size.
# - $s$ : standard deviation.
# - $s_{\bar{x}}$ : estimated standard deviation of the mean.

# %% [markdown]
# #### Ex:1

# %%
from random import randint
data = [randint(0, 100) for _ in range(100)]
mean_data = np.mean(data)
print(mean_data)
# Out:
# 49.03

# %%
from scipy.stats import ttest_1samp
sample_data  = np.random.choice(data, 20)
t_stat, p_value = ttest_1samp(sample_data, mean_data)

# %%
print("Alternate Hypothesis is True") if p_value < 0.05 else print(
    "Null Hypothesis is True")
# Out:
# Alternate Hypothesis is True

# %% [markdown]
# #### Ex:2

# %%
from scipy.stats import poisson

# Setting the seed to reproduce the same results
np.random.seed(0)

# Generating data
school_height = poisson.rvs(loc=18, mu=35, size=1500)
class_a_height = poisson.rvs(loc=18, mu=30, size=50)

# %%
paletts = ['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r']

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))

sns.countplot(x=school_height, ax=ax[0], palette='Blues').set_xticklabels([])
ax[0].set_title("School Height")
sns.countplot(x=class_a_height, ax=ax[1], palette='Blues').set_xticklabels([])
ax[1].set_title("Class A Height")

del fig, ax

# %%
from scipy.stats import ttest_1samp

t_stat, p_value = ttest_1samp(popmean = school_height.mean(), a= class_a_height)
print(p_value)
print("Alternate Hypothesis is True") if p_value < 0.05 else print(
    "Null Hypothesis is True")
# Out:
# 1.0384823698550248e-10
# Alternate Hypothesis is True

# %% [markdown]
# Null Hypothesis: the mean of the above two data sets is same, but just due to chance they are different.
#
# As the p value is less than 0.05, we can reject the null hypothesis i.e mean is different.

# %% [markdown]
# ## Two sample T-test

# %% [markdown]
# The two-sample t-test (also known as the independent samples t-test) is a method used to test whether the unknown population means of two groups are equal or not.
# - Example explination: https://www.statology.org/two-sample-t-test/
#
# $\allowbreak \LARGE{
#     {
#         t = \frac{ \bar{x}_1 - \bar{x}_2}
#              { \sqrt{s ( \frac{1}{n_1} + \frac{1}{n_2} ) } }
#     }
# }$
#
# Where,
#
# $\large{s = \frac{ \displaystyle\sum_{i=1}^{n_1} (x_i - \bar{x}_1)^2 + \sum_{i=1}^{n_2} (x_i - \bar{x}_2)^2 }{ (n_1 + n_2 - 2 )}}$

# %%
from scipy.stats import poisson

# Setting the seed to reproduce the same results
np.random.seed(0)

# Generating data
class_a_height = poisson.rvs(loc=18, mu=30, size=200)
class_b_height = poisson.rvs(loc=18, mu=35, size=200)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))

sns.countplot(x=class_a_height, ax=ax[0], palette='Blues').set_xticklabels([])
ax[0].set_title("Class A Height")
sns.countplot(x=class_b_height, ax=ax[1], palette='Blues').set_xticklabels([])
ax[1].set_title("Class B Height")

del fig, ax

# %%
from scipy.stats import ttest_ind
_, p_value = ttest_ind(class_a_height, class_b_height, equal_var=False)

print(p_value)
print("Alternate Hypothesis is True") if p_value < 0.05 else print(
    "Null Hypothesis is True")
# Out:
# 1.139665533821301e-16
# Alternate Hypothesis is True

# %% [markdown]
# # $Chi^2$ test

# %% [markdown]
# This test is applied when you have two categorical variables froma a single population. It is used to determine whetehr ther is a significant difference between the two groups.

# %%
data = sns.load_dataset('tips')

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# we are gonna check if sex and smoker have an association with each other

# %%
col_1, col_2 = 'sex', 'smoker'
df_table = pd.crosstab(data[col_1], data[col_2])
print(df_table)

del col_1, col_2
# Out:
# smoker  Yes  No
# sex
# Male     60  97
# Female   33  54

# %%
from scipy.stats import chi2_contingency

chi2: float  # The test statistic.
p_val: float  # The p-value of the test
degree_of_freedom: int  # Degrees of freedom
expected: np.array
# The expected frequencies, based on the marginal sums of the table.

chi2, p_val, degree_of_freedom, expected =chi2_contingency(df_table)
print(p_val)

del p_val, degree_of_freedom, expected, chi2
# Out:
# 1.0

# %% [markdown]
# We observed that there is no realtionship between smoker and sex

# %% [markdown]
# # Co-relation

# %%
import seaborn as sns

df = sns.load_dataset('iris')
cm = df.corr()
sns.heatmap(cm, annot=True)

del cm

# %% [markdown]
# From the above heat map we can observe there is some kind of 'linear' realtionship between:
# - petal_length & sepal_length
# - petal_width & sepal_length
# - petal_width & petal_length

# %%
sns.pairplot(data=df, hue='species')

# %% [markdown]
# we can find some similar observation that petal_length, petal_width, sepal_length are linearly co-related with each other.

# %% [markdown]
# # Anova test

# %% [markdown]
# - [Anova : towards data science](https://towardsdatascience.com/statistics-in-python-using-anova-for-feature-selection-b4dc876ef4f0)

# %%
data = """
team,drink_type,reaction_time
1,water,14
2,water,25
3,water,23
4,water,27
5,water,28
6,water,21
7,water,26
8,water,30
9,water,31
10,water,34
1,coke,25 
2,coke,26
3,coke,27
4,coke,29
5,coke,25
6,coke,23
7,coke,22
8,coke,27
9,coke,29
10,coke,21
1,coffee,8
2,coffee,20
3,coffee,26
4,coffee,36
5,coffee,39
6,coffee,23
7,coffee,25
8,coffee,28
9,coffee,27
10,coffee,25
"""

# %%
import io
df = pd.read_csv(io.StringIO(data), sep=',')
df.head()
# Out:
#    team drink_type  reaction_time
# 0     1      water             14
# 1     2      water             25
# 2     3      water             23
# 3     4      water             27
# 4     5      water             28

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))

sns.barplot(x='team', y='reaction_time', hue='drink_type', data=df, ax=ax[0])
sns.boxplot(y='reaction_time', x='drink_type', data=df, ax=ax[1])

del fig, ax

# %%
df = df.pivot(columns='drink_type', index='team')
df
# Out:
#            reaction_time
# drink_type        coffee coke water
# team
# 1                      8   25    14
# 2                     20   26    25
# 3                     26   27    23
# 4                     36   29    27
# 5                     39   25    28
# 6                     23   23    21
# 7                     25   22    26
# 8                     28   27    30
# 9                     27   29    31
# 10                    25   21    34

# %%
from scipy.stats import f_oneway

f_value, p_value = f_oneway(
    *df.iloc[:-1, 0:3].T.values
)

print(p_value)
# Out:
# 0.9457601590112463
