# %%
import numpy as np
import matplotlib.pyplot as plt 
from sklearn import linear_model
import pandas as pd

# %%
df = pd.read_csv('canada_percapita_income.csv',sep = ',')
df.columns

# %%
#drops year income remains therefore y is income
y = df.drop('year',axis = 'columns')
x = df.drop('per capita income (US$)',axis = 'columns')
plt.scatter(x,y)
plt.ylabel('per capita income (US$)')
plt.xlabel('year')
# Out:
# Text(0.5, 0, 'year')

# %%
model = linear_model.LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
print(f'coef : {model.coef_[0][0]}')
print('intercept : ',model.intercept_[0])
# Out:
# coef : 828.4650752227104
# intercept :  -1632210.7578554575

# %%
plt.scatter(x,y,color = 'red')
plt.plot(x,model.predict(x))

# %%
model.predict([[2019]])
# Out:
# array([[40460.22901919]])
